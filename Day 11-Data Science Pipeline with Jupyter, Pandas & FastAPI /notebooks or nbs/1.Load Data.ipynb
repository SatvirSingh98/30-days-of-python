# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
# print(cwd)
BASE_DIR = os.path.dirname(cwd)
# print(BASE_DIR)

DATA_DIR = os.path.join(BASE_DIR, 'data')

# %%
os.listdir(DATA_DIR)
# Out:
# ['2020.csv', '2021.csv', '2018.csv', '2019.csv', '2017.csv']

# %%
# dataframe is a memory efficient way to load csv file in python
# to install something from here:
# !pip install pandas
my_items = [
    {'category': 'action', 'title': 'kung fu hustle'},
    {'category': 'comedy', 'title': 'rush hour'},
]
df = pd.DataFrame(my_items)

# %%
df.head()
# or df
# Out:
#   category           title
# 0   action  kung fu hustle
# 1   comedy       rush hour

# %%
df['category']
# Out:
# 0    action
# 1    comedy
# Name: category, dtype: object

# %%
df['title']
# Out:
# 0    kung fu hustle
# 1         rush hour
# Name: title, dtype: object

# %%
df.iloc[1]
# Out:
# category       comedy
# title       rush hour
# Name: 1, dtype: object

# %%
my_data = os.path.join(DATA_DIR, '2021.csv')
print(os.path.exists(my_data))
# Out:
# True

# %%
df2 = pd.read_csv(my_data)

# %%
df2
# Out:
#      Rank                       Release Group     Worldwide  Domestic      %  \
# 0       1                             Hi, Mom  $677,300,000         -      -
# 1       2               Detective Chinatown 3  $667,144,927         -      -
# 2       3                  A Writer's Odyssey  $125,972,385  $110,779  <0.1%
# 3       4         Boonie Bears: The Wild Life   $77,703,481         -      -
# 4       5                             Endgame   $57,423,149   $23,149  <0.1%
# ..    ...                                 ...           ...       ...    ...
# 162   163                         Money Plane          $618         -      -
# 163   164       Adopt a Daddy 2021 Re-release          $385         -      -
# 164   165                             Békeidö          $361         -      -
# 165   166  Woman on the Beach 2021 Re-release          $160         -      -
# 166   167           Distorted 2021 Re-release          $152         -      -
#
#           Foreign    %.1
# ...

# %%
df2.head(10)
# Out:
#    Rank                Release Group     Worldwide     Domestic      %  \
# 0     1                      Hi, Mom  $677,300,000            -      -
# 1     2        Detective Chinatown 3  $667,144,927            -      -
# 2     3           A Writer's Odyssey  $125,972,385     $110,779  <0.1%
# 3     4  Boonie Bears: The Wild Life   $77,703,481            -      -
# 4     5                      Endgame   $57,423,149      $23,149  <0.1%
# 5     6                 Nazha Reborn   $56,085,073            -      -
# 6     7                Tom and Jerry   $39,710,000  $14,110,000  35.5%
# 7     8           The Yinyang Master   $37,690,000            -      -
# 8     9             Big Red Envelope   $32,800,000            -      -
# 9    10                       Master   $28,692,170            -      -
#
#         Foreign    %.1
# 0  $677,300,000   100%
# 1  $667,144,927   100%
# 2  $125,861,606  99.9%
# 3   $77,703,481   100%
# 4   $57,400,000   100%
# 5   $56,085,073   100%
# ...

# %%
df2.tail(10)
# Out:
#      Rank                       Release Group Worldwide Domestic     %  \
# 157   158                Tuesdays and Fridays    $1,605        -     -
# 158   159                        Elbow Grease      $917     $917  100%
# 159   160                          Automation      $824        -     -
# 160   161                             The Dig      $693        -     -
# 161   162                 Run with the Hunted      $682        -     -
# 162   163                         Money Plane      $618        -     -
# 163   164       Adopt a Daddy 2021 Re-release      $385        -     -
# 164   165                             Békeidö      $361        -     -
# 165   166  Woman on the Beach 2021 Re-release      $160        -     -
# 166   167           Distorted 2021 Re-release      $152        -     -
#
#     Foreign   %.1
# 157  $1,605  100%
# 158       -     -
# 159    $824  100%
# 160    $693  100%
# 161    $682  100%
# 162    $618  100%
# 163    $385  100%
# 164    $361  100%
# ...
